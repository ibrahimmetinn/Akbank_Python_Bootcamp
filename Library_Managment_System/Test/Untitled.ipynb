# %%
class Library:
    def __init__ (self):
        self.book_title=[]         

    def add_book(self,title,author,release_year,num_pages):
        with open("books1.txt","a")as veri:
             veri.write(f"{title},{author},{release_year},{num_pages}\n") 
    def add_book_list(self,title1,author1):
        book_list=f"Book:'{title1}',Author:{author1}"
        self.book_title.append(book_list)
        
    def remove_book(ask):
        # Kitap bilgilerini ekleyen fonksiyon
        silinmek_istenen_kelime = input()
        for öğe in a:
            if öğe.startswith(silinmek_istenen_kelime):
                self.book_title.remove(öğe)

    #menü

lib=Library()
book_index=0


while True:
    print("***MENÜ***")
    print("1-) List Book","2-)Add Book","3-)Read Book",sep="\n")
 
    try:
        d=input("Eylem secin: (q tuşu ile sistemi sonlandırabilirsiniz)")
        
        if d =="q":
            print("Program kapatılıyor")
            break
        #kitap ekleme bölümü
        elif d=="2":
            print("Eklemek istediginiz kitabı secin",end="\n")
            title1 = input("Kitap Adı:").strip()
            author1 = input("Yazar Adı:").strip()
            release_year1 = int(input("Hangi yıl yayımlandı:"))
            num_pages1 = int(input("Sayfa Sayısı:"))
            title1=Library()
            #txt dosyasına ekleme
            add_book(title1,author1,release_year1,num_pages1)
            #listeye ekleme
            add_book_list(title1,lib)
            book_index+=1
        #kitap liste bölümü
        elif d=="1":
            print("Liste bölümü")
            print(lib.book_title)
        #kitap remove bölümü
        elif d=="3":
            print("remove bölümü")
            ask=input("kitap_adını_gitiniz:")
            remove_book(ask)
        else:
            print("Try Again")
        
        
        
        
    
    except ValueError:
        print("yanlis deger girdiniz")
        
        
#add books
